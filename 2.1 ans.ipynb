# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Analysis of literacy Rate and total crime
# 1. Literacy Rate have been taken from https://www.careindia.org/blog/literacy-rate-in-india/
# 2. Total Crime have been added using sum if formula in excel

# %%
df=pd.read_csv('qus 1.csv')
df.head()
# Out:
#             STATE/UT  Total Population  Literacy Rate  Total Crimes  MURDER  \
# 0     ANDHRA PRADESH          84580777          67.02       2018981   31756
# 1  ARUNACHAL PRADESH           1383727          65.38         27652     841
# 2              ASSAM          31205576          72.19        597764   15432
# 3              BIHAR         104099452          61.80       1346293   41245
# 4       CHHATTISGARH          25545198          70.28        561027   12060
#
#    ATTEMPT TO MURDER  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER   RAPE  \
# 0              22420                                       1763  13479
# 1                388                                         35    500
# 2               4992                                        664  16178
# 3              35467                                       3387  13124
# 4               7317                                        322  11838
#
#    CUSTODIAL RAPE  OTHER RAPE  ...  COUNTERFIETING  ARSON  HURT/GREVIOUS HURT  \
# ...

# %%
#checking Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             35 non-null     object
#  1   Total Population                                     35 non-null     int64
#  2   Literacy Rate                                        35 non-null     float64
#  3   Total Crimes                                         35 non-null     int64
#  4   MURDER                                               35 non-null     int64
#  5   ATTEMPT TO MURDER                                    35 non-null     int64
#  6   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            35 non-null     int64
#  7   RAPE                                                 35 non-null     int64
# ...

# %%
x= pd.DataFrame(df.groupby(['Literacy Rate'])['Total Crimes'].sum().reset_index())
x
# Out:
#     Literacy Rate  Total Crimes
# 0           61.80       1346293
# 1           65.38         27652
# 2           66.11       1855916
# 3           66.41        422351
# 4           67.02       2018981
# 5           67.16        259155
# 6           67.68       1858074
# 7           69.32       2413770
# 8           70.28        561027
# 9           72.19        597764
# 10          72.87        647946
# 11          74.43         25249
# 12          75.36       1481063
# 13          75.55        595303
# 14          75.84        384131
# 15          76.24          4651
# 16          76.26       1119304
# 17          76.94         35072
# 18          78.03       1385775
# 19          78.82        103204
# 20          79.55         13133
# 21          80.09       2060176
# 22          81.42          7000
# 23          82.34       2273436
# 24          82.80        154948
# 25          85.85         54116
# 26          86.05         40807
# 27          86.21       1266348
# ...

# %%
plt.bar(x['Literacy Rate'], df['Total Crimes'], color ='maroon',
        width = 0.4)
plt.xlabel("Literacy Rate")
plt.ylabel("Total Crimes")
plt.title("Literacy and Total crimes")
plt.show()

# %%
#By plotting the above graph it has been been observed that higher the literacy rate lower will be crime 
#In some placed where literacy rate is higher but crime also lower due to small area and small U/T

# %%
plt.figure(figsize=(20,10))
sns.set_style('whitegrid')
sns.pointplot(x='Literacy Rate', y='Total Crimes', data=df,join=False)
plt.title('Literacy and Total crimesn', fontsize=22, fontweight='bold')
plt.xlabel('Total Crimes',{'fontsize':15,'fontweight' :'bold'})
plt.ylabel('Total Crimes',{'fontsize':15,'fontweight' :'bold'})
plt.xticks(fontsize=16,fontweight ='bold')
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=14)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.corr()
# Out:
#                                                     Total Population  \
# Total Population                                            1.000000
# Literacy Rate                                              -0.468256
# Total Crimes                                                0.820197
# MURDER                                                      0.966638
# ATTEMPT TO MURDER                                           0.932696
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                   0.804735
# RAPE                                                        0.717277
# CUSTODIAL RAPE                                                   NaN
# OTHER RAPE                                                  0.716768
# KIDNAPPING & ABDUCTION                                      0.766548
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                 0.792266
# KIDNAPPING AND ABDUCTION OF OTHERS                          0.594442
# DACOITY                                                     0.680590
# ...

# %%
ax = plt.subplots(figsize=(50,50))        
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu",linewidths=2,annot=True)

# %%
#Analysis of the type of crime vs each state vs Literacy rate.

# %%
df=pd.read_csv('District wise crime.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   YEAR                                                 9017 non-null   int64
#  3   MURDER                                               9017 non-null   int64
#  4   ATTEMPT TO MURDER                                    9017 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9017 non-null   int64
#  6   RAPE                                                 9017 non-null   int64
#  7   CUSTODIAL RAPE                                       9017 non-null   int64
# ...

# %%
plt.bar(df['YEAR'], df['TOTAL IPC CRIMES'], color ='#37c916',
        width = 0.4)
plt.xlabel("Year")
plt.ylabel("TOTAL IPC CRIMES ")
plt.title("TOTAL IPC CRIMES")
plt.show()

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
x= pd.DataFrame(df.groupby(['STATE/UT'])['MURDER', 'ATTEMPT TO MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
       'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
       'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
       'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
       'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
       'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
       'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
       'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
       'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES'].sum().reset_index())
x
# Out:
#              STATE/UT  MURDER  ATTEMPT TO MURDER  \
# 0       A & N ISLANDS     320                130
# 1      ANDHRA PRADESH   63512              44840
# 2   ARUNACHAL PRADESH    1682                834
# 3               ASSAM   30864              11324
# 4               BIHAR   82490              81838
# 5          CHANDIGARH     486                602
# 6        CHHATTISGARH   24120              15820
# 7        D & N HAVELI     216                 62
# 8         DAMAN & DIU     136                 76
# 9            DELHI UT   12410              10554
# 10                GOA     974                538
# 11            GUJARAT   27550              12224
# 12            HARYANA   20942              14868
# 13   HIMACHAL PRADESH    2908               1670
# 14    JAMMU & KASHMIR   12608              20606
# 15          JHARKHAND   38120              24540
# 16          KARNATAKA   39874              37024
# 17             KERALA    9466              10654
# ...

# %%
plt.bar(df['STATE/UT'], df['MURDER'], color ='#37c916',
        width = 0.5)
plt.xlabel("STATE/UT")
plt.ylabel("MURDER ")
plt.title("Murder in states")
plt.show()

# %%
#line plot(use after above year segrigate)
plt.figure(figsize=(20,10))
sns.set_style('whitegrid')
sns.pointplot(x='STATE/UT', y='MURDER', data=df,join=False)
plt.title('STATE/UT vs TOTAL MURDER', fontsize=22, fontweight='bold')
plt.xlabel('STATE/UT',{'fontsize':15,'fontweight' :'bold'})
plt.ylabel('MURDER',{'fontsize':15,'fontweight' :'bold'})
plt.xticks(fontsize=16,fontweight ='bold')
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=14)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.describe()
# Out:
#               YEAR      MURDER  ATTEMPT TO MURDER  \
# count  9017.000000  9017.00000        9017.000000
# mean   2006.629034    89.28535          78.069646
# std       3.463623   327.27503         303.446020
# min    2001.000000     0.00000           0.000000
# 25%    2004.000000    18.00000          10.000000
# 50%    2007.000000    38.00000          28.000000
# 75%    2010.000000    66.00000          56.000000
# max    2012.000000  7601.00000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9017.000000  9017.000000     9017.000000
# mean                                    9.895531    53.041366        0.005767
# std                                    59.521657   190.741450        0.115223
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
sns.heatmap(x.isnull())
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (9017, 33)

# %%
#There are multiple columns with same type of crime so we add them to reduce columns and dropping total crimes
df['rape_victims']= df['RAPE']+df['CUSTODIAL RAPE'] + df['OTHER RAPE']
# df['kid_abd_victims']= df['KIDNAPPING & ABDUCTION']+df['KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS'] + df['KIDNAPPING AND ABDUCTION OF OTHERS']
# df['married_women_victims']= df['DOWRY DEATHS']+df['ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY'] + df['INSULT TO MODESTY OF WOMEN']+df['CRUELTY BY HUSBAND OR HIS RELATIVES']
# df['murder_cases']= df['MURDER']+df['ATTEMPT TO MURDER'] + df['CULPABLE HOMICIDE NOT AMOUNTING TO MURDER']
# df['theft_cases']= df['DACOITY']+df['PREPARATION AND ASSEMBLY FOR DACOITY'] + df['ROBBERY']+ df['BURGLARY'] +df['THEFT'] + df['AUTO THEFT'] +df['OTHER THEFT']

# %%
df.shape
# Out:
# (9017, 38)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'rape_victims', 'kid_abd_victims', 'married_women_victims',
#        'murder_cases', 'theft_cases'],
#       dtype='object')

# %%
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
ax = df.plot(x="STATE/UT", y=['MURDER', 'ATTEMPT TO MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE'], kind="bar", rot=0)
ax
# Out:
# <Axes: xlabel='STATE/UT'>

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'rape_victims', 'kid_abd_victims', 'married_women_victims',
#        'murder_cases', 'theft_cases'],
#       dtype='object')
